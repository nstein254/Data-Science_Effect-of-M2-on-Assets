# %%
import pandas as pd

# %%
data_correct = pd.DataFrame(data={"Date": ["01.01.2010", "02.01.2010", "03.01.2010", "04.01.2010", "05.01.2010"], "Data": [1,2,3,4,5]})
data_correct["Date"] = pd.to_datetime(data_correct["Date"])

# %%
data_false = pd.DataFrame(data={"Date": ["01.01.2010", "02.01.2010", "03.01.2010", "04.01.2010", "05.01.2010", "06.01.2010", "07.01.2010"], "Data": [7,6,5,4,3,2,1]})
data_false["Date"] = pd.to_datetime(data_false["Date"])

# %%
data_false
# Out:
#         Date  Data
# 0 2010-01-01     7
# 1 2010-02-01     6
# 2 2010-03-01     5
# 3 2010-04-01     4
# 4 2010-05-01     3
# 5 2010-06-01     2
# 6 2010-07-01     1

# %%
data_correct
# Out:
#         Date  Data
# 0 2010-01-01     1
# 1 2010-02-01     2
# 2 2010-03-01     3
# 3 2010-04-01     4
# 4 2010-05-01     5

# %%
data_false_corrected = data_false[data_false["Date"].isin(data_correct["Date"])]

# %%
data_false_corrected
# Out:
#         Date  Data
# 0 2010-01-01     7
# 1 2010-02-01     6
# 2 2010-03-01     5
# 3 2010-04-01     4
# 4 2010-05-01     3

# %%
import yfinance as yf

# %%
# BTC-USD = Bitcoin, GC=F = Gold Future, ^SPX = S&P500, CL=F = Crude Oil Future
yfinance_data = yf.download(["BTC-USD", "GC=F", "^SPX", "CL=F"], start="2000-01-01", end="2025-01-01", interval="1wk")
# Out:
# /tmp/ipython-input-4038365591.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   yfinance_data = yf.download(["BTC-USD", "GC=F", "^SPX", "CL=F"], start="2000-01-01", end="2025-01-01", interval="1wk")
# [*********************100%***********************]  4 of 4 completed

# %%
yfinance_data
# Out:
# Price              Close                                     High  \
# Ticker           BTC-USD         GC=F         ^SPX        BTC-USD
# Date
# 2000-01-01           NaN          NaN  1441.469971            NaN
# 2000-01-08           NaN          NaN  1465.150024            NaN
# 2000-01-15           NaN          NaN  1441.359985            NaN
# 2000-01-22           NaN          NaN  1360.160034            NaN
# 2000-01-29           NaN          NaN  1424.369995            NaN
# ...                  ...          ...          ...            ...
# 2024-12-16  95104.937500  2628.699951          NaN  108268.445312
# 2024-12-21           NaN          NaN  5970.839844            NaN
# 2024-12-23  93530.226562  2617.199951          NaN   99884.570312
# 2024-12-28           NaN          NaN  5881.629883            NaN
# 2024-12-30  94419.757812  2629.199951          NaN   96090.601562
#
# Price                                          Low                            \
# ...
